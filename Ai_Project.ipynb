# %%
import json

class Cities:
    def _init_(self):
        self.cities = {}
        self.heuristics = {}

    def create_cities(self, city_names):
        for city in city_names:
            self.cities[city] = 0

    def create_heuristics(self, heuristics):
        self.heuristics = heuristics

    def a_star(self, start, goal):
        pass

    def greedy(self, start, goal):
        pass

    def save_to_json(self, data, filename):
        with open(filename, 'w') as f:
            json.dump(data, f)

# %%
def main():
  cities = Cities()

  city_names = ['Gaza', 'Cairo', 'Amman', 'Makkah', 'Dubai', 'Damascus', 'Yafa', 'Morocco']
  cities.create_cities(city_names)

  heuristics = {
    'Gaza': 75,
    'Cairo': 60,
    'Amman': 45,
    'Makkah': 25,
    'Dubai': 40,
    'Damascus': 30,
    'Yafa': 20,
    'Morocco': 201
}
  cities.create_heuristics(heuristics)

  output = cities.a_star('Gaza', 'Morocco')
  cities.save_to_json(output, 'a_star.json')

  output = cities.greedy('Gaza', 'Morocco')
  cities.save_to_json(output, 'greedy.json')

# %%
################################################################################

# %%
class Cities:
    def _init_(self):
        self.cities = {}
        self.heuristics = {}

    def create_cities(self, cities_list):
        self.cities = {city: heuristic for city, heuristic in cities_list}

    def create_heuristics(self, heuristics_list):
        self.heuristics = {city: heuristic for city, heuristic in heuristics_list}

    def a_star(self, start, end):
        pass

    def greedy(self, start, end):
        pass

# %%
cities_list = [("Gaza", 75), ("Cairo", 60), ("Amman", 45), ("Makkah", 45), ("Dubai", 25), ("Damascus", 40), ("Yafa", 30), ("Morocco", 0)]

cities = Cities()

cities.create_cities(cities_list)
cities.create_heuristics(cities_list)

shortest_path = cities.a_star("Morocco", "Gaza")

shortest_path = cities.greedy("Morocco", "Gaza")

# %%
################################################################################

# %%
def createCities():
  cities = {
    "Gaza": {"Cairo": 75, "Amman": 45, "Makkah": 45, "Dubai": 25, "Damascus": 40, "Yafa": 30, "Morocco": 0},
    "Cairo": {"Gaza": 75, "Amman": 40, "Makkah": 50, "Dubai": 30, "Damascus": 35, "Yafa": 25, "Morocco": 20},
    "Amman": {"Gaza": 45, "Cairo": 40, "Makkah": 30, "Dubai": 35, "Damascus": 20, "Yafa": 15, "Morocco": 10},
    "Makkah": {"Gaza": 45, "Cairo": 50, "Amman": 30, "Dubai": 25, "Damascus": 35, "Yafa": 20, "Morocco": 15},
    "Dubai": {"Gaza": 25, "Cairo": 30, "Amman": 35, "Makkah": 25, "Damascus": 40, "Yafa": 15, "Morocco": 10},
    "Damascus": {"Gaza": 40, "Cairo": 35, "Amman": 20, "Makkah": 35, "Dubai": 40, "Yafa": 10, "Morocco": 15},
    "Yafa": {"Gaza": 30, "Cairo": 25, "Amman": 15, "Makkah": 20, "Dubai": 15, "Damascus": 10, "Morocco": 5},
    "Morocco": {"Gaza": 0, "Cairo": 20, "Amman": 10, "Makkah": 15, "Dubai": 10, "Damascus": 15, "Yafa": 5}
  }

  city_dict = createCities(cities)
  print(city_dict)

  hueristic = {
      "Gaza":75,
      "Cairo":60,
      "Amman":45,
      "Makkah":45,
      "Dubai":25,
      "Damascus":40,
      "Yafa":30,
      "Morocco":0
  }

  import json  

class Cities:
  def __init__(self, name, country, population, connections):
    self.name = name
    self.country = country
    self.population = population
    self.connections = connections

    def createCities(cities):
        city_dict = {}
        for city in cities:
            city_dict[city.name] = city.connections
        return city_dict

    def __init__(self):
        self.cities = {}

    def main():
     cities = createCities()
     citiesObj = Cities(cities)        
    
    def createH(self, city, heuristic):
        self.cities[city] = heuristic
    
    def path_cost(self, path):
        total = 0
        for (node, cost) in path:
            total += cost
        return total + self.cities.get(path[-1][0])
    
    def a_star(self, start, goal):
        visited = []
        queue = [[(start, 0)]]
        while queue:
            queue.sort(key=self.path_cost)
            path = queue.pop(-1)
            node = path[-1][0]
            if node not in visited:
                visited.append(node)

            if node == goal:
                return path
            else:
                a = self.cities.get(node, [])
                for (child_node, cost) in a:
                    new_path = path.copy()
                    new_path.append((child_node, cost))
                    queue.append(new_path)

    def greedy(self, start, goal):
      self.result = greedy
  
    def save_to_json(self, file_name):
      output = {"greeay_result": self.result}
    
    with open(cities, "w") as f:
      json.dump(cities, f)

      obj = cities()
      obj.greedy(cities)
      obj.save_to_json("cities.json")
    
    def save_to_json(self):
        with open('cities.json', 'w') as f:
            json.dump(self.cities, f)
            cities.save_to_json()

    def main():
      cities = Cities()

    while True:
        print("Main menu:")
        print("1. Add city and heuristic")
        print("2. A* algorithm")
        print("3. Greedy algorithm")
        print("4. Exit")
        choice = input("Enter your choice: ")
        
        if choice == "1":
            city = input("Enter city name: ")
            heuristic = input("Enter heuristic value: ")
            cities.createH(city, heuristic)
        elif choice == "2":
            start = input("Enter start city: ")
            goal = input("Enter goal city: ")
            cities.a_star(start, goal)
        elif choice == "3":
            start = input("Enter start city: ")
            goal = input("Enter goal city: ")
            cities.greedy(start, goal)
        elif choice == "4":
            break
        else:
            print("Invalid choice. Try again.")

    path = cities(cities)
    path = a_star(cities)
    path = greedy(cities)
    path = exit(cities)
    print("Main menu:")
    print("1. Add city and heuristic")
    print("2. A* algorithm")
    print("3. Greedy algorithm")
    print("4. Exit")
    choice = input("Enter your choice: ")

    print('The Max road is from : ', path)

    if __name__ == "__main__":
            main()
